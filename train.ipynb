# %% [markdown]
# ## Importing dependencies

# %%
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import  VecMonitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import CheckpointCallback
import metadrive

# %% [markdown]
# ### Creating a MetaDrive environment

# %%
config = {
    "use_render": False,
    "manual_control": False,
    "traffic_density": 0.3,
    "map": "X",   
    "random_lane_width": True,
    "random_agent_model": True,
    "random_traffic": True,
    "map": 5,  
    "num_agents": 1,
    "allow_respawn": True
}

env = metadrive.MetaDriveEnv(config)
# Out:
# [INFO] Environment: MetaDriveEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 1000

# %% [markdown]
# ## Exploring the environment

# %%
print(env.observation_space)   
print(env.action_space)
# Out:
# Box(-0.0, 1.0, (261,), float32)
# Box(-1.0, 1.0, (2,), float32)

# %%
obs = env.reset()
for step in range(10):
    action = env.action_space.sample()   # random action
    obs, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    if done:
        obs, info = env.reset()
# Out:
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1

# %%
env.close()

# %% [markdown]
# ## Training a PPO model

# %%
model= PPO("MlpPolicy", env, verbose=1,tensorboard_log="./tb_logs",)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\yby39\anaconda3\envs\self_driving\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
ckpt_cb = CheckpointCallback(save_freq=100000, save_path="./checkpoints/", name_prefix="ppo_metadrive")

# %%
model.learn(total_timesteps=1000000, callback=ckpt_cb)
# Out:
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# Logging to ./tb_logs\PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 434      |
# |    ep_rew_mean     | 0.834    |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 132      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 622          |
# |    ep_rew_mean          | 4.02         |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 2            |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0057820645 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0195       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.168        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00125     |
# |    std                  | 0.999        |
# |    value_loss           | 0.274        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 702         |
# |    ep_rew_mean          | 6.39        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 3           |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018336307 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.158       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.972       |
# |    value_loss           | 0.00864     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 645         |
# |    ep_rew_mean          | 6.41        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 4           |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015239967 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | -0.000433   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0152      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.964       |
# |    value_loss           | 0.131       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 8.34        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 5           |
# |    time_elapsed         | 832         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008630022 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.0411      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.159       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00425    |
# |    std                  | 0.956       |
# |    value_loss           | 0.388       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | 8.85        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 6           |
# |    time_elapsed         | 1028        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007870708 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.0551      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.148       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00368    |
# |    std                  | 0.951       |
# |    value_loss           | 0.401       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 544         |
# |    ep_rew_mean          | 9.23        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 7           |
# |    time_elapsed         | 1224        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010925116 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.0484      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00667    |
# |    std                  | 0.945       |
# |    value_loss           | 0.754       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 503         |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 1417        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008657315 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.0265      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.299       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00351    |
# |    std                  | 0.941       |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 444          |
# |    ep_rew_mean          | 10.2         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 9            |
# |    time_elapsed         | 1608         |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0053577083 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.423        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.562        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00455     |
# |    std                  | 0.937        |
# |    value_loss           | 0.844        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | 9.94         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 10           |
# |    time_elapsed         | 1792         |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0052425982 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.54         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.382        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00224     |
# |    std                  | 0.926        |
# |    value_loss           | 1.18         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 11          |
# |    time_elapsed         | 1995        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006299789 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.358       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00812    |
# |    std                  | 0.917       |
# |    value_loss           | 0.716       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 310          |
# |    ep_rew_mean          | 9.54         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 12           |
# |    time_elapsed         | 2180         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0077427067 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.69         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.207        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.909        |
# |    value_loss           | 1.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 283         |
# |    ep_rew_mean          | 9.16        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 13          |
# |    time_elapsed         | 2369        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007627328 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | -0.0387     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00443    |
# |    std                  | 0.913       |
# |    value_loss           | 5.64        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 259          |
# |    ep_rew_mean          | 9.98         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 14           |
# |    time_elapsed         | 2561         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0049593165 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.65        |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00316     |
# |    std                  | 0.911        |
# |    value_loss           | 2.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 180          |
# |    ep_rew_mean          | 9.79         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 15           |
# |    time_elapsed         | 2760         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0048862696 |
# |    clip_fraction        | 0.0922       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.68         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00678     |
# |    std                  | 0.902        |
# |    value_loss           | 2            |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 163           |
# |    ep_rew_mean          | 10.5          |
# | time/                   |               |
# |    fps                  | 11            |
# |    iterations           | 16            |
# |    time_elapsed         | 2965          |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00076701713 |
# |    clip_fraction        | 0.0211        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.62         |
# |    explained_variance   | 0.205         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.72          |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000938     |
# |    std                  | 0.891         |
# |    value_loss           | 5.13          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 10.8         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 17           |
# |    time_elapsed         | 3169         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0045405747 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.952        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.882        |
# |    value_loss           | 2.51         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 11          |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 18          |
# |    time_elapsed         | 3368        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007601219 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00892    |
# |    std                  | 0.879       |
# |    value_loss           | 6.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 12          |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 19          |
# |    time_elapsed         | 3560        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008878594 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000431    |
# |    std                  | 0.876       |
# |    value_loss           | 2.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 20          |
# |    time_elapsed         | 3762        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008763908 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0063     |
# |    std                  | 0.866       |
# |    value_loss           | 3.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 14          |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 21          |
# |    time_elapsed         | 3963        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005792585 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000534    |
# |    std                  | 0.858       |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 15.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 22          |
# |    time_elapsed         | 4173        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008132656 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00134    |
# |    std                  | 0.849       |
# |    value_loss           | 3.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 15.5        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 23          |
# |    time_elapsed         | 4372        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.027537905 |
# |    clip_fraction        | 0.0924      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00219     |
# |    std                  | 0.842       |
# |    value_loss           | 3.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 17.2        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 24          |
# |    time_elapsed         | 4569        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007997022 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00721    |
# |    std                  | 0.838       |
# |    value_loss           | 6.37        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 159        |
# |    ep_rew_mean          | 18.8       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 25         |
# |    time_elapsed         | 4773       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01380149 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | 0.631      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.8        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00202   |
# |    std                  | 0.824      |
# |    value_loss           | 4.32       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 19.9        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 26          |
# |    time_elapsed         | 4982        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009660177 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.819       |
# |    value_loss           | 5.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 21.2        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 27          |
# |    time_elapsed         | 5186        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011367645 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 0.816       |
# |    value_loss           | 6.67        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 28           |
# |    time_elapsed         | 5383         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0064099776 |
# |    clip_fraction        | 0.0947       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.42        |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.88         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00214     |
# |    std                  | 0.809        |
# |    value_loss           | 9.27         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 20.1        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 29          |
# |    time_elapsed         | 5587        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.017688675 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.57        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00661    |
# |    std                  | 0.805       |
# |    value_loss           | 9.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 19          |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 30          |
# |    time_elapsed         | 5788        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008434806 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.42        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00477    |
# |    std                  | 0.807       |
# |    value_loss           | 8.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 31          |
# |    time_elapsed         | 5994        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.040595744 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.08        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.798       |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 115        |
# |    ep_rew_mean          | 20         |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 32         |
# |    time_elapsed         | 6193       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01331168 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.205      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.01       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00802   |
# |    std                  | 0.793      |
# |    value_loss           | 11.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 33          |
# |    time_elapsed         | 6403        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.015726693 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.87        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00955    |
# |    std                  | 0.787       |
# |    value_loss           | 11.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 34          |
# |    time_elapsed         | 6619        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.024533175 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00836    |
# |    std                  | 0.786       |
# |    value_loss           | 14          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 126          |
# |    ep_rew_mean          | 25.4         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 35           |
# |    time_elapsed         | 6825         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0104566375 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.2          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00226     |
# |    std                  | 0.78         |
# |    value_loss           | 9.72         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 29.7        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 36          |
# |    time_elapsed         | 7040        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010787506 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00949    |
# |    std                  | 0.777       |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 33           |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 37           |
# |    time_elapsed         | 7266         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0053781965 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.298        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.36         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00189      |
# |    std                  | 0.759        |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 148        |
# |    ep_rew_mean          | 35.2       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 38         |
# |    time_elapsed         | 7468       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01079683 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.28      |
# |    explained_variance   | 0.438      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10         |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00311   |
# |    std                  | 0.752      |
# |    value_loss           | 14.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 35.2        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 39          |
# |    time_elapsed         | 7661        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.033353735 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00396     |
# |    std                  | 0.743       |
# |    value_loss           | 22.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 39.5        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 40          |
# |    time_elapsed         | 7862        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008733923 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0059      |
# |    std                  | 0.729       |
# |    value_loss           | 16.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 41          |
# |    time_elapsed         | 8079        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021630356 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00675    |
# |    std                  | 0.729       |
# |    value_loss           | 23.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 147        |
# |    ep_rew_mean          | 42.6       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 42         |
# |    time_elapsed         | 8287       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00843115 |
# |    clip_fraction        | 0.126      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.324      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.12       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00525   |
# |    std                  | 0.725      |
# |    value_loss           | 20.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 39.4        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 43          |
# |    time_elapsed         | 8494        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.020134822 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.522       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.000419    |
# |    std                  | 0.718       |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | 41.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 44          |
# |    time_elapsed         | 8704        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018083258 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.395       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00968    |
# |    std                  | 0.712       |
# |    value_loss           | 27.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 46.2        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 45          |
# |    time_elapsed         | 8919        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011414019 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.57        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00249     |
# |    std                  | 0.707       |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 46          |
# |    time_elapsed         | 9143        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.019251084 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.307       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.99        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00799     |
# |    std                  | 0.699       |
# |    value_loss           | 21.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 57.1        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 47          |
# |    time_elapsed         | 9374        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010566777 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.000794    |
# |    std                  | 0.693       |
# |    value_loss           | 27.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | 62.6         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 48           |
# |    time_elapsed         | 9607         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0074832295 |
# |    clip_fraction        | 0.196        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00647      |
# |    std                  | 0.687        |
# |    value_loss           | 19.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 166        |
# |    ep_rew_mean          | 64.6       |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 49         |
# |    time_elapsed         | 9832       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01573056 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.543      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.29       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00218   |
# |    std                  | 0.69       |
# |    value_loss           | 18.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | 70.9        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 50          |
# |    time_elapsed         | 10066       |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.021519173 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00733    |
# |    std                  | 0.688       |
# |    value_loss           | 43          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 76.3        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 51          |
# |    time_elapsed         | 10296       |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.012074145 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.55        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00837     |
# |    std                  | 0.671       |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 79.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 52          |
# |    time_elapsed         | 10519       |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.020950284 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.668       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 63.5        |
# | time/                   |             |
# ...
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 3270        |
# |    policy_gradient_loss | 0.0155      |
# |    std                  | 0.303       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.2        |
# |    ep_rew_mean          | 68.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 329         |
# |    time_elapsed         | 72841       |
# |    total_timesteps      | 673792      |
# | train/                  |             |
# |    approx_kl            | 0.007942681 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0233     |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 3280        |
# |    policy_gradient_loss | 0.00597     |
# |    std                  | 0.305       |
# |    value_loss           | 22.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.5        |
# |    ep_rew_mean          | 69          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 330         |
# |    time_elapsed         | 73066       |
# |    total_timesteps      | 675840      |
# | train/                  |             |
# |    approx_kl            | 0.010605555 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0225     |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.75        |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | 0.000849    |
# |    std                  | 0.303       |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.9        |
# |    ep_rew_mean          | 68.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 331         |
# |    time_elapsed         | 73291       |
# |    total_timesteps      | 677888      |
# | train/                  |             |
# |    approx_kl            | 0.021492925 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.00433    |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 3300        |
# |    policy_gradient_loss | 0.00235     |
# |    std                  | 0.3         |
# |    value_loss           | 21.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91          |
# |    ep_rew_mean          | 68.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 332         |
# |    time_elapsed         | 73519       |
# |    total_timesteps      | 679936      |
# | train/                  |             |
# |    approx_kl            | 0.013434931 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00248     |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55        |
# |    n_updates            | 3310        |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.299       |
# |    value_loss           | 13.3        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 90.2      |
# |    ep_rew_mean          | 67.5      |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 333       |
# |    time_elapsed         | 73744     |
# |    total_timesteps      | 681984    |
# | train/                  |           |
# |    approx_kl            | 0.0085966 |
# |    clip_fraction        | 0.132     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.00915   |
# |    explained_variance   | 0.882     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.49      |
# |    n_updates            | 3320      |
# |    policy_gradient_loss | -0.00501  |
# |    std                  | 0.296     |
# |    value_loss           | 19.8      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.6        |
# |    ep_rew_mean          | 71          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 334         |
# |    time_elapsed         | 73970       |
# |    total_timesteps      | 684032      |
# | train/                  |             |
# |    approx_kl            | 0.025721058 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.022       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69        |
# |    n_updates            | 3330        |
# |    policy_gradient_loss | 0.0119      |
# |    std                  | 0.294       |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.7        |
# |    ep_rew_mean          | 69.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 335         |
# |    time_elapsed         | 74199       |
# |    total_timesteps      | 686080      |
# | train/                  |             |
# |    approx_kl            | 0.030479435 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0457      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.9         |
# |    n_updates            | 3340        |
# |    policy_gradient_loss | 0.00773     |
# |    std                  | 0.288       |
# |    value_loss           | 17.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | 67.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 336         |
# |    time_elapsed         | 74427       |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.014502492 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0829      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.81        |
# |    n_updates            | 3350        |
# |    policy_gradient_loss | -0.000738   |
# |    std                  | 0.283       |
# |    value_loss           | 12.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.7        |
# |    ep_rew_mean          | 69          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 337         |
# |    time_elapsed         | 74651       |
# |    total_timesteps      | 690176      |
# | train/                  |             |
# |    approx_kl            | 0.023217363 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.101       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.08        |
# |    n_updates            | 3360        |
# |    policy_gradient_loss | 0.00242     |
# |    std                  | 0.282       |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.3        |
# |    ep_rew_mean          | 67.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 338         |
# |    time_elapsed         | 74880       |
# |    total_timesteps      | 692224      |
# | train/                  |             |
# |    approx_kl            | 0.007382861 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.112       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96        |
# |    n_updates            | 3370        |
# |    policy_gradient_loss | 0.00168     |
# |    std                  | 0.28        |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.6        |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 339         |
# |    time_elapsed         | 75108       |
# |    total_timesteps      | 694272      |
# | train/                  |             |
# |    approx_kl            | 0.007394977 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.129       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.31        |
# |    n_updates            | 3380        |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.28        |
# |    value_loss           | 17.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.5        |
# |    ep_rew_mean          | 68.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 340         |
# |    time_elapsed         | 75334       |
# |    total_timesteps      | 696320      |
# | train/                  |             |
# |    approx_kl            | 0.010587404 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.131       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.47        |
# |    n_updates            | 3390        |
# |    policy_gradient_loss | 0.00641     |
# |    std                  | 0.28        |
# |    value_loss           | 19.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.5       |
# |    ep_rew_mean          | 68.2       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 341        |
# |    time_elapsed         | 75558      |
# |    total_timesteps      | 698368     |
# | train/                  |            |
# |    approx_kl            | 0.01599923 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.119      |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.87       |
# |    n_updates            | 3400       |
# |    policy_gradient_loss | 0.0013     |
# |    std                  | 0.281      |
# |    value_loss           | 15.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.2        |
# |    ep_rew_mean          | 67.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 342         |
# |    time_elapsed         | 75783       |
# |    total_timesteps      | 700416      |
# | train/                  |             |
# |    approx_kl            | 0.021307781 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.122       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 3410        |
# |    policy_gradient_loss | 0.00942     |
# |    std                  | 0.278       |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.5        |
# |    ep_rew_mean          | 68.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 343         |
# |    time_elapsed         | 76009       |
# |    total_timesteps      | 702464      |
# | train/                  |             |
# |    approx_kl            | 0.010232698 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.138       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.86        |
# |    n_updates            | 3420        |
# |    policy_gradient_loss | -0.000616   |
# |    std                  | 0.276       |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88          |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 344         |
# |    time_elapsed         | 76234       |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.011930611 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.138       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.14        |
# |    n_updates            | 3430        |
# |    policy_gradient_loss | -0.00234    |
# |    std                  | 0.276       |
# |    value_loss           | 17.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.5        |
# |    ep_rew_mean          | 66          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 345         |
# |    time_elapsed         | 76459       |
# |    total_timesteps      | 706560      |
# | train/                  |             |
# |    approx_kl            | 0.022286298 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.126       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.06        |
# |    n_updates            | 3440        |
# |    policy_gradient_loss | -0.000116   |
# |    std                  | 0.279       |
# |    value_loss           | 13.1        |
# -----------------------------------------

# %% [markdown]
# The model stopped training after 700k steps, so i had to load the last model from checkpoints and continue training it.

# %%
model = PPO.load("./checkpoints/ppo_metadrive_700000_steps", env=env, tensorboard_log="./tb_logs")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=200000, callback=ckpt_cb)
# Out:
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# Logging to ./tb_logs\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81.4     |
# |    ep_rew_mean     | 56.7     |
# | time/              |          |
# |    fps             | 9        |
# |    iterations      | 1        |
# |    time_elapsed    | 217      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.4        |
# |    ep_rew_mean          | 61.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 2           |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007942596 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.125       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.64        |
# |    n_updates            | 3420        |
# |    policy_gradient_loss | -0.00166    |
# |    std                  | 0.281       |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.9        |
# |    ep_rew_mean          | 61.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 3           |
# |    time_elapsed         | 656         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.034417618 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.11        |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72        |
# |    n_updates            | 3430        |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.283       |
# |    value_loss           | 13.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87          |
# |    ep_rew_mean          | 64.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 4           |
# |    time_elapsed         | 871         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012191404 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.106       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.51        |
# |    n_updates            | 3440        |
# |    policy_gradient_loss | 0.00327     |
# |    std                  | 0.283       |
# |    value_loss           | 23.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.5         |
# |    ep_rew_mean          | 67.1         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 5            |
# |    time_elapsed         | 1090         |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0145024825 |
# |    clip_fraction        | 0.183        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.118        |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.57         |
# |    n_updates            | 3450         |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.279        |
# |    value_loss           | 18.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.1        |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 6           |
# |    time_elapsed         | 1304        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008938857 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.134       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 3460        |
# |    policy_gradient_loss | 0.00392     |
# |    std                  | 0.278       |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.1        |
# |    ep_rew_mean          | 67.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 7           |
# |    time_elapsed         | 1519        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010476233 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.132       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.18        |
# |    n_updates            | 3470        |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.279       |
# |    value_loss           | 19          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 89.5       |
# |    ep_rew_mean          | 68.2       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 8          |
# |    time_elapsed         | 1733       |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00971893 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.132      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.42       |
# |    n_updates            | 3480       |
# |    policy_gradient_loss | 0.00515    |
# |    std                  | 0.28       |
# |    value_loss           | 17.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.4        |
# |    ep_rew_mean          | 68.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 9           |
# |    time_elapsed         | 1957        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014773273 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.139       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.51        |
# |    n_updates            | 3490        |
# |    policy_gradient_loss | 0.00261     |
# |    std                  | 0.279       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.5        |
# |    ep_rew_mean          | 67          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 10          |
# |    time_elapsed         | 2174        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021242848 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.142       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.33        |
# |    n_updates            | 3500        |
# |    policy_gradient_loss | 0.00178     |
# |    std                  | 0.282       |
# |    value_loss           | 23.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.2        |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 11          |
# |    time_elapsed         | 2392        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014719693 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.149       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.18        |
# |    n_updates            | 3510        |
# |    policy_gradient_loss | -0.00465    |
# |    std                  | 0.28        |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | 64.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 12          |
# |    time_elapsed         | 2606        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014884813 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.166       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.68        |
# |    n_updates            | 3520        |
# |    policy_gradient_loss | 0.00542     |
# |    std                  | 0.278       |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.7        |
# |    ep_rew_mean          | 64.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 13          |
# |    time_elapsed         | 2819        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016637802 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.181       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.32        |
# |    n_updates            | 3530        |
# |    policy_gradient_loss | 0.00132     |
# |    std                  | 0.277       |
# |    value_loss           | 17.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.7        |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 14          |
# |    time_elapsed         | 3034        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008313533 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.192       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.05        |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | 0.00342     |
# |    std                  | 0.275       |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.3        |
# |    ep_rew_mean          | 67.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 15          |
# |    time_elapsed         | 3251        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023078218 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.199       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72        |
# |    n_updates            | 3550        |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.275       |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.8        |
# |    ep_rew_mean          | 68.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 16          |
# |    time_elapsed         | 3474        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010584011 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.203       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.73        |
# |    n_updates            | 3560        |
# |    policy_gradient_loss | 0.0122      |
# |    std                  | 0.273       |
# |    value_loss           | 18.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91          |
# |    ep_rew_mean          | 71.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 17          |
# |    time_elapsed         | 3690        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.012058426 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.226       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.67        |
# |    n_updates            | 3570        |
# |    policy_gradient_loss | 0.00638     |
# |    std                  | 0.268       |
# |    value_loss           | 20.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 90.2        |
# |    ep_rew_mean          | 70.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 18          |
# |    time_elapsed         | 3907        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010529565 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.232       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.56        |
# |    n_updates            | 3580        |
# |    policy_gradient_loss | -0.00452    |
# |    std                  | 0.267       |
# |    value_loss           | 18.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.9        |
# |    ep_rew_mean          | 70.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 19          |
# |    time_elapsed         | 4119        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013636535 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.231       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 3590        |
# |    policy_gradient_loss | -0.0054     |
# |    std                  | 0.267       |
# |    value_loss           | 30.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.4        |
# |    ep_rew_mean          | 68.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 20          |
# |    time_elapsed         | 4318        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014760885 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.232       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.7        |
# |    n_updates            | 3600        |
# |    policy_gradient_loss | -0.00827    |
# |    std                  | 0.268       |
# |    value_loss           | 30.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.3        |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 21          |
# |    time_elapsed         | 4526        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009613713 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.246       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.21        |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.000355   |
# |    std                  | 0.266       |
# |    value_loss           | 23.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.5        |
# |    ep_rew_mean          | 64.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 22          |
# |    time_elapsed         | 4745        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012139502 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.257       |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.3        |
# |    n_updates            | 3620        |
# |    policy_gradient_loss | -0.000617   |
# |    std                  | 0.268       |
# |    value_loss           | 32.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.7        |
# |    ep_rew_mean          | 63.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 23          |
# |    time_elapsed         | 4964        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011542393 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.258       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.67        |
# |    n_updates            | 3630        |
# |    policy_gradient_loss | 0.00438     |
# |    std                  | 0.268       |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85          |
# |    ep_rew_mean          | 63.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 24          |
# |    time_elapsed         | 5178        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022851594 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.26        |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 3640        |
# |    policy_gradient_loss | 0.0032      |
# |    std                  | 0.269       |
# |    value_loss           | 19.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 84.2       |
# |    ep_rew_mean          | 62.5       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 25         |
# |    time_elapsed         | 5395       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02710697 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.257      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.61       |
# |    n_updates            | 3650       |
# |    policy_gradient_loss | -0.000388  |
# |    std                  | 0.269      |
# |    value_loss           | 20.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.7        |
# |    ep_rew_mean          | 64.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 26          |
# |    time_elapsed         | 5613        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.014963023 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.256       |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.52        |
# |    n_updates            | 3660        |
# |    policy_gradient_loss | 0.0054      |
# |    std                  | 0.269       |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.8        |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 27          |
# |    time_elapsed         | 5830        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.017378608 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.261       |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 3670        |
# |    policy_gradient_loss | -0.000496   |
# |    std                  | 0.268       |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.5        |
# |    ep_rew_mean          | 67.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 28          |
# |    time_elapsed         | 6047        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011333805 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.263       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.47        |
# |    n_updates            | 3680        |
# |    policy_gradient_loss | 0.00993     |
# |    std                  | 0.269       |
# |    value_loss           | 28.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89          |
# |    ep_rew_mean          | 69.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 29          |
# |    time_elapsed         | 6253        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.026605193 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.273       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.87        |
# |    n_updates            | 3690        |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 0.267       |
# |    value_loss           | 28.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.9        |
# |    ep_rew_mean          | 66.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 30          |
# |    time_elapsed         | 6454        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010249208 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.285       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.74        |
# |    n_updates            | 3700        |
# |    policy_gradient_loss | -0.00406    |
# |    std                  | 0.267       |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.5        |
# |    ep_rew_mean          | 67.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 31          |
# |    time_elapsed         | 6672        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013730323 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.3         |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47        |
# |    n_updates            | 3710        |
# |    policy_gradient_loss | 0.00196     |
# |    std                  | 0.265       |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.5        |
# |    ep_rew_mean          | 67.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 32          |
# |    time_elapsed         | 6892        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020276502 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.309       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.7         |
# |    n_updates            | 3720        |
# |    policy_gradient_loss | -0.00224    |
# |    std                  | 0.264       |
# |    value_loss           | 22          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 67.2       |
# |    ep_rew_mean          | 42.6       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 33         |
# |    time_elapsed         | 7094       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.12054868 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.316      |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.9        |
# |    n_updates            | 3730       |
# |    policy_gradient_loss | 0.00804    |
# |    std                  | 0.264      |
# |    value_loss           | 20.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.9        |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 34          |
# |    time_elapsed         | 7298        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010533123 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.322       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.59        |
# |    n_updates            | 3740        |
# |    policy_gradient_loss | 0.00713     |
# |    std                  | 0.263       |
# |    value_loss           | 19.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 45.1       |
# |    ep_rew_mean          | 14.8       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 35         |
# |    time_elapsed         | 7502       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.03645857 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.335      |
# |    explained_variance   | 0.421      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.48       |
# |    n_updates            | 3750       |
# |    policy_gradient_loss | 0.00384    |
# |    std                  | 0.262      |
# |    value_loss           | 18.5       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 51.2       |
# |    ep_rew_mean          | 22.1       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 36         |
# |    time_elapsed         | 7713       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01688606 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.362      |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.8       |
# |    n_updates            | 3760       |
# |    policy_gradient_loss | -0.00939   |
# |    std                  | 0.259      |
# |    value_loss           | 18.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.2        |
# |    ep_rew_mean          | 33.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 37          |
# |    time_elapsed         | 7930        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.018501509 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.378       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 3770        |
# |    policy_gradient_loss | -0.00769    |
# |    std                  | 0.261       |
# |    value_loss           | 27.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.9        |
# |    ep_rew_mean          | 45.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 38          |
# |    time_elapsed         | 8149        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.035988763 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.372       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.63        |
# |    n_updates            | 3780        |
# |    policy_gradient_loss | 0.00317     |
# |    std                  | 0.261       |
# |    value_loss           | 16.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.4        |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 39          |
# |    time_elapsed         | 8370        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015119188 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.365       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.37        |
# |    n_updates            | 3790        |
# |    policy_gradient_loss | -0.000468   |
# |    std                  | 0.263       |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.1        |
# |    ep_rew_mean          | 63.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 40          |
# |    time_elapsed         | 8577        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.048375145 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.355       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.63        |
# |    n_updates            | 3800        |
# |    policy_gradient_loss | 0.0262      |
# |    std                  | 0.262       |
# |    value_loss           | 13          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.4        |
# |    ep_rew_mean          | 62.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 41          |
# |    time_elapsed         | 8780        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010082731 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.349       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 3810        |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.263       |
# |    value_loss           | 39.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83         |
# |    ep_rew_mean          | 62.1       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 42         |
# |    time_elapsed         | 8986       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01655756 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.354      |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.2       |
# |    n_updates            | 3820       |
# |    policy_gradient_loss | -0.00553   |
# |    std                  | 0.262      |
# |    value_loss           | 27.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.8        |
# |    ep_rew_mean          | 63.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 43          |
# |    time_elapsed         | 9182        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013503109 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.353       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.45        |
# |    n_updates            | 3830        |
# |    policy_gradient_loss | 0.00375     |
# |    std                  | 0.263       |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84          |
# |    ep_rew_mean          | 63.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 44          |
# |    time_elapsed         | 9404        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010022961 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.366       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.54        |
# |    n_updates            | 3840        |
# |    policy_gradient_loss | -0.00535    |
# |    std                  | 0.259       |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83          |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 45          |
# |    time_elapsed         | 9621        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.034932755 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.383       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 3850        |
# |    policy_gradient_loss | 0.00227     |
# |    std                  | 0.26        |
# |    value_loss           | 34.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.8        |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 46          |
# |    time_elapsed         | 9841        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011946233 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.376       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.7        |
# |    n_updates            | 3860        |
# |    policy_gradient_loss | -0.000659   |
# |    std                  | 0.263       |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.3        |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 47          |
# |    time_elapsed         | 10069       |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.024893204 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.365       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 3870        |
# |    policy_gradient_loss | 0.000585    |
# |    std                  | 0.262       |
# |    value_loss           | 24.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.9        |
# |    ep_rew_mean          | 57.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 48          |
# |    time_elapsed         | 10289       |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027546871 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.364       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.7         |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | 0.00488     |
# |    std                  | 0.263       |
# |    value_loss           | 17.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.5        |
# |    ep_rew_mean          | 61.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 49          |
# |    time_elapsed         | 10507       |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013809586 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.363       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 3890        |
# |    policy_gradient_loss | -0.000492   |
# |    std                  | 0.263       |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.6        |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 50          |
# |    time_elapsed         | 10725       |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.013046574 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.366       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | 0.000948    |
# |    std                  | 0.262       |
# |    value_loss           | 30.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.8        |
# |    ep_rew_mean          | 66.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 51          |
# |    time_elapsed         | 10942       |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.026122756 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.366       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 3910        |
# |    policy_gradient_loss | -0.00185    |
# |    std                  | 0.263       |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87          |
# |    ep_rew_mean          | 68.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 52          |
# |    time_elapsed         | 11169       |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.019107992 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.356       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 3920        |
# |    policy_gradient_loss | 0.00744     |
# |    std                  | 0.266       |
# |    value_loss           | 25          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.2        |
# |    ep_rew_mean          | 67.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 53          |
# |    time_elapsed         | 11390       |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.027338585 |
# |    clip_fraction        | 0.286       |
# ...
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.79         |
# |    n_updates            | 4210         |
# |    policy_gradient_loss | 0.0131       |
# |    std                  | 0.252        |
# |    value_loss           | 12.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.7        |
# |    ep_rew_mean          | 62.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 82          |
# |    time_elapsed         | 17631       |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.015585083 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.5         |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 4220        |
# |    policy_gradient_loss | 0.0191      |
# |    std                  | 0.253       |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.8        |
# |    ep_rew_mean          | 64.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 83          |
# |    time_elapsed         | 17849       |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.011903757 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.495       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 4230        |
# |    policy_gradient_loss | 0.000947    |
# |    std                  | 0.254       |
# |    value_loss           | 23.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.2        |
# |    ep_rew_mean          | 65.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 84          |
# |    time_elapsed         | 18064       |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.019976307 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.504       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.6         |
# |    n_updates            | 4240        |
# |    policy_gradient_loss | 0.00792     |
# |    std                  | 0.254       |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | 64.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 85          |
# |    time_elapsed         | 18283       |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.023540292 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.504       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.83        |
# |    n_updates            | 4250        |
# |    policy_gradient_loss | 0.0047      |
# |    std                  | 0.255       |
# |    value_loss           | 16.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.6        |
# |    ep_rew_mean          | 65.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 86          |
# |    time_elapsed         | 18498       |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.016273597 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.493       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.61        |
# |    n_updates            | 4260        |
# |    policy_gradient_loss | 0.00595     |
# |    std                  | 0.257       |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.2        |
# |    ep_rew_mean          | 65          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 87          |
# |    time_elapsed         | 18715       |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.025341684 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.483       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 4270        |
# |    policy_gradient_loss | 0.0066      |
# |    std                  | 0.259       |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | 65.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 88          |
# |    time_elapsed         | 18929       |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.010898838 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.47        |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.7        |
# |    n_updates            | 4280        |
# |    policy_gradient_loss | 0.000917    |
# |    std                  | 0.262       |
# |    value_loss           | 18.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84          |
# |    ep_rew_mean          | 66.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 89          |
# |    time_elapsed         | 19145       |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.010287795 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.473       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.45        |
# |    n_updates            | 4290        |
# |    policy_gradient_loss | 0.00344     |
# |    std                  | 0.259       |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.5       |
# |    ep_rew_mean          | 62.3       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 90         |
# |    time_elapsed         | 19358      |
# |    total_timesteps      | 184320     |
# | train/                  |            |
# |    approx_kl            | 0.02579445 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.496      |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.15       |
# |    n_updates            | 4300       |
# |    policy_gradient_loss | 0.00613    |
# |    std                  | 0.256      |
# |    value_loss           | 16.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.2        |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 91          |
# |    time_elapsed         | 19577       |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.023851851 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.505       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62        |
# |    n_updates            | 4310        |
# |    policy_gradient_loss | 0.00443     |
# |    std                  | 0.255       |
# |    value_loss           | 15.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.1        |
# |    ep_rew_mean          | 60.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 92          |
# |    time_elapsed         | 19801       |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.012001821 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.514       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.33        |
# |    n_updates            | 4320        |
# |    policy_gradient_loss | 0.00821     |
# |    std                  | 0.254       |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.9        |
# |    ep_rew_mean          | 60          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 93          |
# |    time_elapsed         | 20014       |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.015203206 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.521       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.87        |
# |    n_updates            | 4330        |
# |    policy_gradient_loss | -0.00169    |
# |    std                  | 0.253       |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.6        |
# |    ep_rew_mean          | 62.8        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 94          |
# |    time_elapsed         | 20228       |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.017315425 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.539       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1         |
# |    n_updates            | 4340        |
# |    policy_gradient_loss | 0.00356     |
# |    std                  | 0.249       |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 81.9       |
# |    ep_rew_mean          | 63.4       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 95         |
# |    time_elapsed         | 20463      |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.03612584 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.564      |
# |    explained_variance   | 0.826      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.1       |
# |    n_updates            | 4350       |
# |    policy_gradient_loss | 0.00309    |
# |    std                  | 0.249      |
# |    value_loss           | 21.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83          |
# |    ep_rew_mean          | 65.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 96          |
# |    time_elapsed         | 20667       |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.022794243 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.578       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28        |
# |    n_updates            | 4360        |
# |    policy_gradient_loss | 0.00462     |
# |    std                  | 0.25        |
# |    value_loss           | 15.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.8         |
# |    ep_rew_mean          | 65.3         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 97           |
# |    time_elapsed         | 20871        |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0122878635 |
# |    clip_fraction        | 0.174        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.599        |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.12         |
# |    n_updates            | 4370         |
# |    policy_gradient_loss | -0.00119     |
# |    std                  | 0.245        |
# |    value_loss           | 14.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.6        |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 98          |
# |    time_elapsed         | 21076       |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.020140901 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.617       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85        |
# |    n_updates            | 4380        |
# |    policy_gradient_loss | 0.00225     |
# |    std                  | 0.245       |
# |    value_loss           | 16.8        |
# -----------------------------------------

# %%
model.save("ppo_highway")

# %% [markdown]
# ## Visualizing how the model is performing

# %%
config = {
    "use_render": True,
    "manual_control": False,
    "traffic_density": 0.3,
    "map": "X",   
    "random_lane_width": True,
    "random_agent_model": True,
    "random_traffic": True,
    "map": 5,  
    "num_agents": 1,
}

nenv = metadrive.envs.MetaDriveEnv(config)
model = PPO.load("ppo_highway")
# Out:
# [INFO] Environment: MetaDriveEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector(), main_camera: MainCamera(1200, 900), dashboard: DashBoard()]
# [INFO] Render Mode: onscreen
# [INFO] Horizon (Max steps per agent): 1000
# C:\Users\yby39\anaconda3\envs\self_driving\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
for episode in range(2):  
    obs, info = nenv.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)  
        obs, reward, terminated, truncated, info = nenv.step(action)
        total_reward += reward
        nenv.render(mode="human")   

    print(f"Episode {episode} reward: {total_reward}")
# Out:
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: wglGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# * interrupt by keyboard
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 while not done:
#       7     action, _ = model.predict(obs, deterministic=True)
# ----> 8     obs, reward, terminated, truncated, info = nenv.step(action)
#       9     total_reward += reward
#      10     nenv.render(mode="human")
#
# File c:\users\yby39\self-driving-car\metadrive\metadrive\envs\base_env.py:437, in BaseEnv.step(self, actions)
#     435 def step(self, actions: Union[Union[np.ndarray, list], Dict[AnyStr, Union[list, np.ndarray]], int]):
#     436     actions = self._preprocess_actions(actions)  # preprocess environment input
# --> 437     engine_info = self._step_simulator(actions)  # step the simulation
#     438     while self.in_stop:
#     439         self.engine.taskMgr.step()  # pause simulation
#
# File c:\users\yby39\self-driving-car\metadrive\metadrive\envs\base_env.py:466, in BaseEnv._step_simulator(self, actions)
#     464 scene_manager_before_step_infos = self.engine.before_step(actions)
#     465 # step all entities and the simulator
# --> 466 self.engine.step(self.config["decision_repeat"])
#     467 # update states, if restore from episode data, position and heading will be force set in update_state() function
#     468 scene_manager_after_step_infos = self.engine.after_step()
#
# File c:\users\yby39\self-driving-car\metadrive\metadrive\engine\base_engine.py:458, in BaseEngine.step(self, step_num)
#     455         self.task_manager.step()
#     457 #  Do rendering
# --> 458 self.task_manager.step()
#     459 if self.on_screen_message is not None:
#     460     self.on_screen_message.render()
#
# File ~\anaconda3\envs\self_driving\Lib\site-packages\direct\task\Task.py:517, in TaskManager.step(self)
#     514         self.__prevHandler = signal.default_int_handler
#     516 if self.fKeyboardInterrupt:
# --> 517     raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
nenv.close()

# %% [markdown]
# ## Using tensorboard to see metrics

# %%
#!tensorboard --logdir=./tb_logs
